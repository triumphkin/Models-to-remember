# %% [markdown]
# # Linear Regression
#
# In linear regression we try to fit a line(hyperplane).
# $ \hat{y}(w,b) = wx + b $ (in case of <b>one</b> independent variable)
# or
# $ \hat{y} = w_{1}x_{1} + w_{2}x_{2} + ..... + w_{n}x_{n} + b$ (in case of <b>multiple</b> independent variables)

# %% [markdown]
# Main idea is to <i><b>minimize value cost function</b></i> by adjusting model parameters w and b using <i><b>gradient descent optimization</b></i>
# this would ensure we get the best fit line

# %% [markdown]
# ## Cost function

# %% [markdown]
# In this case we are using MSE (mean squared error) as cost function
#
#
# $ L(y, \hat{y}) = \frac{1}{n} \sum_{i=1}^{n} (y_i  - \hat{y}_i)^{2} $
#
# Here $ y $ is true values and $ \hat{y} $ is predicted value and n is total number of values
#
# $ \hat{y}=wx + b $

# %% [markdown]
# ### partial derivatives of cost function (can be easily calculated using chain rule or as you wish)

# %% [markdown]
# w.r.t weight,
#
# $ d(L)_w = -(2/n) \sum_{i=1}^{n} x_{i}(y_i  - \hat{y}_i) $
#
# w.r.t bias,
#
#   $ d(L)_w = -(2/n) \sum_{i=1}^{n} (y_i  - \hat{y}_i) $

# %% [markdown]
# ## Gradient descent

# %% [markdown]
# it is an <b>optimaization algorithm</b> , used to <b>minimize the cost function</b>. it updates model parameters.
# Gradient means derivative and descent means decreasing or downward.
#
# $ w = w - R * d(L)_w $
# $ b = b - R * d(L)_b $
#
# here w is weight, b is bias, R is learning rate, $ d(L)_w $  is derivative of cost function wrt to weight and $ d(L)_b $ is derivative of cost function wrt to bias
# Learning rate is a tuning parameter, it denotes how much jump to take per iteration
# Negative sign denotes that we are going down the slope

# %% [markdown]
# ## Note: Since Loss function contains a squared term $ (y - \hat{y})^2 $ so its graph is parabolic, hence after initally selecting random weight and bias we need to constanly go down to achieve minima which is the point where our loss is minimum and giving us best values of w and b.

# %%
import numpy as np

class LinearRegression:

    def __init__(self, learning_rate: float , no_of_iterations: int):
        self.R = learning_rate
        self.n = no_of_iterations
    
    def fit(self, X_train: np.array, Y_train: np.array):
        self.rows, self.columns = X_train.shape
        self.w = np.ones(self.columns)
        self.b = 1
        self.X = X_train
        self.Y = Y_train
        for i in range(self.n):
            self.update_weights()
            print(f"for iternation {i+1} weight is {self.w} and bias is {self.b}")

    def update_weights(self):

        self.w -= (self.R)*(-2/self.rows)*(((self.X.T).dot((self.Y-self.predict(self.X)))))
        self.b -= (self.R)*(-2/self.rows)*(np.sum((self.Y-self.predict(self.X))))

    def predict(self, X_test: np.array):
        return X_test.dot(self.w) + self.b

# %%
import pandas as pd
df = pd.read_csv("D:/Ml/part1/data/salary_data.csv")

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
X = df.drop(columns=["Salary"]).values
Y = df['Salary'].values
type(X)
# Out:
# numpy.ndarray

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (24, 1)

# %%
Y_train.shape
# Out:
# (24,)

# %%
model = LinearRegression(0.00005,1000)
model.fit(X_train=X_train, Y_train=Y_train)
# Out:
# for iternation 1 weight is [47.31396304] and bias is 8.396118381672135
# for iternation 2 weight is [93.46101209] and bias is 15.767558369810306
# for iternation 3 weight is [139.44174768] and bias is 23.114408707362582
# for iternation 4 weight is [185.25676818] and bias is 30.43675781800018
# for iternation 5 weight is [230.90666979] and bias is 37.73469380726617
# for iternation 6 weight is [276.39204658] and bias is 45.008304463719995
# for iternation 7 weight is [321.7134905] and bias is 52.25767726007794
# for iternation 8 weight is [366.87159133] and bias is 59.48289935434946
# for iternation 9 weight is [411.86693676] and bias is 66.68405759096943
# for iternation 10 weight is [456.70011235] and bias is 73.86123850192631
# for iternation 11 weight is [501.37170157] and bias is 81.01452830788625
# for iternation 12 weight is [545.88228577] and bias is 88.14401291931318
# for iternation 13 weight is [590.23244421] and bias is 95.24977793758487
# for iternation 14 weight is [634.42275409] and bias is 102.33190865610487
# for iternation 15 weight is [678.45379051] and bias is 109.39049006141065
# for iternation 16 weight is [722.32612651] and bias is 116.42560683427753
# for iternation 17 weight is [766.04033306] and bias is 123.43734335081884
# for iternation 18 weight is [809.59697909] and bias is 130.42578368358195
# for iternation 19 weight is [852.99663147] and bias is 137.3910116026405
# for iternation 20 weight is [896.23985503] and bias is 144.3331105766826
# for iternation 21 weight is [939.32721259] and bias is 151.2521637740951
# for iternation 22 weight is [982.25926491] and bias is 158.14825406404412
# for iternation 23 weight is [1025.03657077] and bias is 165.0214640175515
# for iternation 24 weight is [1067.65968691] and bias is 171.87187590856746
# for iternation 25 weight is [1110.12916807] and bias is 178.6995717150395
# for iternation 26 weight is [1152.44556702] and bias is 185.50463311997717
# for iternation 27 weight is [1194.60943451] and bias is 192.28714151251336
# for iternation 28 weight is [1236.62131933] and bias is 199.0471779889615
# for iternation 29 weight is [1278.48176828] and bias is 205.78482335386914
# for iternation 30 weight is [1320.1913262] and bias is 212.50015812106764
# for iternation 31 weight is [1361.75053598] and bias is 219.19326251471801
# for iternation 32 weight is [1403.15993853] and bias is 225.86421647035323
# for iternation 33 weight is [1444.42007285] and bias is 232.51309963591655
# for iternation 34 weight is [1485.53147596] and bias is 239.13999137279626
# for iternation 35 weight is [1526.49468299] and bias is 245.7449707568566
# for iternation 36 weight is [1567.31022711] and bias is 252.328116579465
# for iternation 37 weight is [1607.9786396] and bias is 258.88950734851574
# for iternation 38 weight is [1648.5004498] and bias is 265.4292212894497
# for iternation 39 weight is [1688.87618516] and bias is 271.94733634627056
# for iternation 40 weight is [1729.10637124] and bias is 278.44393018255755
# for iternation 41 weight is [1769.19153169] and bias is 284.91908018247415
# for iternation 42 weight is [1809.1321883] and bias is 291.37286345177336
# for iternation 43 weight is [1848.92886097] and bias is 297.8053568187995
# for iternation 44 weight is [1888.58206772] and bias is 304.21663683548627
# for iternation 45 weight is [1928.09232473] and bias is 310.606779778351
# for iternation 46 weight is [1967.46014629] and bias is 316.97586164948575
# for iternation 47 weight is [2006.68604487] and bias is 323.32395817754457
# for iternation 48 weight is [2045.77053108] and bias is 329.6511448187273
# for iternation 49 weight is [2084.71411371] and bias is 335.95749675775966
# for iternation 50 weight is [2123.51729969] and bias is 342.24308890887016
# for iternation 51 weight is [2162.18059415] and bias is 348.5079959167632
# for iternation 52 weight is [2200.7045004] and bias is 354.75229215758867
# for iternation 53 weight is [2239.08951993] and bias is 360.97605173990826
# for iternation 54 weight is [2277.33615244] and bias is 367.1793485056582
# for iternation 55 weight is [2315.44489581] and bias is 373.3622560311085
# for iternation 56 weight is [2353.41624614] and bias is 379.52484762781853
# for iternation 57 weight is [2391.25069777] and bias is 385.66719634358986
# for iternation 58 weight is [2428.94874321] and bias is 391.78937496341484
# for iternation 59 weight is [2466.51087325] and bias is 397.8914560104222
# for iternation 60 weight is [2503.93757687] and bias is 403.9735117468192
# for iternation 61 weight is [2541.22934133] and bias is 410.03561417483047
# for iternation 62 weight is [2578.38665211] and bias is 416.0778350376332
# for iternation 63 weight is [2615.40999294] and bias is 422.1002458202892
# for iternation 64 weight is [2652.29984585] and bias is 428.1029177506737
# for iternation 65 weight is [2689.05669108] and bias is 434.08592180040034
# for iternation 66 weight is [2725.68100718] and bias is 440.0493286857434
# for iternation 67 weight is [2762.17327098] and bias is 445.99320886855634
# for iternation 68 weight is [2798.53395756] and bias is 451.9176325571872
# for iternation 69 weight is [2834.76354032] and bias is 457.8226697073906
# for iternation 70 weight is [2870.86249096] and bias is 463.7083900232367
# for iternation 71 weight is [2906.83127946] and bias is 469.57486295801635
# for iternation 72 weight is [2942.67037412] and bias is 475.4221577151437
# for iternation 73 weight is [2978.38024158] and bias is 481.25034324905505
# for iternation 74 weight is [3013.96134675] and bias is 487.0594882661045
# for iternation 75 weight is [3049.41415291] and bias is 492.84966122545666
# for iternation 76 weight is [3084.73912165] and bias is 498.62093033997604
# for iternation 77 weight is [3119.93671292] and bias is 504.373363577113
# for iternation 78 weight is [3155.007385] and bias is 510.10702865978686
# for iternation 79 weight is [3189.95159452] and bias is 515.8219930672655
# for iternation 80 weight is [3224.76979647] and bias is 521.518324036042
# for iternation 81 weight is [3259.4624442] and bias is 527.1960885607084
# for iternation 82 weight is [3294.02998945] and bias is 532.8553533948254
# for iternation 83 weight is [3328.4728823] and bias is 538.4961850517903
# for iternation 84 weight is [3362.79157125] and bias is 544.1186498057003
# for iternation 85 weight is [3396.98650314] and bias is 549.722813692214
# for iternation 86 weight is [3431.05812325] and bias is 555.308742509409
# for iternation 87 weight is [3465.00687522] and bias is 560.8765018186366
# for iternation 88 weight is [3498.83320112] and bias is 566.4261569453738
# for iternation 89 weight is [3532.53754141] and bias is 571.9577729800716
# for iternation 90 weight is [3566.12033498] and bias is 577.4714147790007
# for iternation 91 weight is [3599.58201914] and bias is 582.9671469650942
# for iternation 92 weight is [3632.92302961] and bias is 588.4450339287868
# for iternation 93 weight is [3666.14380056] and bias is 593.9051398288512
# for iternation 94 weight is [3699.2447646] and bias is 599.3475285932323
# for iternation 95 weight is [3732.22635276] and bias is 604.7722639198764
# for iternation 96 weight is [3765.08899455] and bias is 610.1794092775602
# for iternation 97 weight is [3797.83311791] and bias is 615.5690279067142
# for iternation 98 weight is [3830.45914926] and bias is 620.9411828202444
# for iternation 99 weight is [3862.96751347] and bias is 626.2959368043513
# for iternation 100 weight is [3895.35863388] and bias is 631.6333524193452
# for iternation 101 weight is [3927.63293233] and bias is 636.9534920004592
# for iternation 102 weight is [3959.79082911] and bias is 642.2564176586584
# for iternation 103 weight is [3991.83274303] and bias is 647.5421912814473
# for iternation 104 weight is [4023.75909136] and bias is 652.8108745336739
# for iternation 105 weight is [4055.57028991] and bias is 658.0625288583301
# for iternation 106 weight is [4087.26675295] and bias is 663.2972154773504
# for iternation 107 weight is [4118.84889329] and bias is 668.5149953924071
# for iternation 108 weight is [4150.31712225] and bias is 673.7159293857026
# for iternation 109 weight is [4181.67184965] and bias is 678.9000780207595
# for iternation 110 weight is [4212.91348386] and bias is 684.0675016432066
# for iternation 111 weight is [4244.04243177] and bias is 689.2182603815635
# for iternation 112 weight is [4275.0590988] and bias is 694.3524141480214
# for iternation 113 weight is [4305.96388894] and bias is 699.4700226392213
# for iternation 114 weight is [4336.75720468] and bias is 704.5711453370299
# for iternation 115 weight is [4367.4394471] and bias is 709.6558415093119
# for iternation 116 weight is [4398.01101583] and bias is 714.7241702107003
# for iternation 117 weight is [4428.47230904] and bias is 719.7761902833631
# for iternation 118 weight is [4458.8237235] and bias is 724.8119603577682
# for iternation 119 weight is [4489.06565453] and bias is 729.8315388534446
# for iternation 120 weight is [4519.19849603] and bias is 734.8349839797418
# for iternation 121 weight is [4549.2226405] and bias is 739.8223537365853
# for iternation 122 weight is [4579.138479] and bias is 744.793705915231
# for iternation 123 weight is [4608.9464012] and bias is 749.7490980990151
# for iternation 124 weight is [4638.64679538] and bias is 754.6885876641024
# for iternation 125 weight is [4668.24004839] and bias is 759.612231780232
# for iternation 126 weight is [4697.72654572] and bias is 764.5200874114596
# for iternation 127 weight is [4727.10667146] and bias is 769.4122113168975
# for iternation 128 weight is [4756.38080832] and bias is 774.288660051452
# for iternation 129 weight is [4785.54933762] and bias is 779.1494899665583
# for iternation 130 weight is [4814.61263932] and bias is 783.9947572109126
# for iternation 131 weight is [4843.57109203] and bias is 788.8245177312007
# for iternation 132 weight is [4872.42507297] and bias is 793.6388272728259
# for iternation 133 weight is [4901.17495801] and bias is 798.4377413806325
# for iternation 134 weight is [4929.82112167] and bias is 803.2213153996274
# for iternation 135 weight is [4958.36393713] and bias is 807.9896044756995
# for iternation 136 weight is [4986.80377622] and bias is 812.7426635563353
# for iternation 137 weight is [5015.14100944] and bias is 817.4805473913336
# for iternation 138 weight is [5043.37600593] and bias is 822.2033105335163
# for iternation 139 weight is [5071.50913354] and bias is 826.9110073394368
# for iternation 140 weight is [5099.54075878] and bias is 831.6036919700866
# for iternation 141 weight is [5127.47124683] and bias is 836.2814183915989
# for iternation 142 weight is [5155.30096156] and bias is 840.9442403759493
# for iternation 143 weight is [5183.03026556] and bias is 845.5922115016546
# for iternation 144 weight is [5210.65952007] and bias is 850.2253851544685
# for iternation 145 weight is [5238.18908506] and bias is 854.8438145280758
# for iternation 146 weight is [5265.61931921] and bias is 859.4475526247826
# for iternation 147 weight is [5292.95057988] and bias is 864.0366522562055
# for iternation 148 weight is [5320.18322318] and bias is 868.611166043957
# for iternation 149 weight is [5347.3176039] and bias is 873.17114642033
# for iternation 150 weight is [5374.35407559] and bias is 877.7166456289781
# for iternation 151 weight is [5401.2929905] and bias is 882.2477157255944
# for iternation 152 weight is [5428.13469963] and bias is 886.7644085785884
# for iternation 153 weight is [5454.87955272] and bias is 891.2667758697589
# for iternation 154 weight is [5481.52789823] and bias is 895.7548690949662
# for iternation 155 weight is [5508.08008339] and bias is 900.2287395648004
# for iternation 156 weight is [5534.53645416] and bias is 904.6884384052485
# for iternation 157 weight is [5560.89735528] and bias is 909.134016558358
# for iternation 158 weight is [5587.16313022] and bias is 913.5655247828992
# for iternation 159 weight is [5613.33412125] and bias is 917.9830136550244
# for iternation 160 weight is [5639.41066937] and bias is 922.3865335689247
# for iternation 161 weight is [5665.39311438] and bias is 926.7761347374852
# for iternation 162 weight is [5691.28179484] and bias is 931.1518671929366
# for iternation 163 weight is [5717.07704812] and bias is 935.5137807875057
# for iternation 164 weight is [5742.77921034] and bias is 939.8619251940627
# for iternation 165 weight is [5768.38861644] and bias is 944.1963499067668
# for iternation 166 weight is [5793.90560013] and bias is 948.5171042417089
# for iternation 167 weight is [5819.33049394] and bias is 952.8242373375522
# for iternation 168 weight is [5844.6636292] and bias is 957.1177981561707
# for iternation 169 weight is [5869.90533604] and bias is 961.3978354832855
# for iternation 170 weight is [5895.0559434] and bias is 965.6643979290978
# for iternation 171 weight is [5920.11577905] and bias is 969.9175339289214
# for iternation 172 weight is [5945.08516958] and bias is 974.157291743811
# for iternation 173 weight is [5969.96444038] and bias is 978.3837194611896
# for iternation 174 weight is [5994.7539157] and bias is 982.5968649954731
# for iternation 175 weight is [6019.45391861] and bias is 986.7967760886928
# for iternation 176 weight is [6044.06477102] and bias is 990.9835003111156
# for iternation 177 weight is [6068.58679368] and bias is 995.1570850618617
# for iternation 178 weight is [6093.02030619] and bias is 999.317577569521
# for iternation 179 weight is [6117.36562698] and bias is 1003.4650248927655
# for iternation 180 weight is [6141.62307338] and bias is 1007.5994739209622
# for iternation 181 weight is [6165.79296152] and bias is 1011.7209713747806
# for iternation 182 weight is [6189.87560644] and bias is 1015.8295638068008
# for iternation 183 weight is [6213.87132203] and bias is 1019.9252976021178
# for iternation 184 weight is [6237.78042104] and bias is 1024.008218978944
# for iternation 185 weight is [6261.60321511] and bias is 1028.0783739892095
# for iternation 186 weight is [6285.34001475] and bias is 1032.1358085191612
# for iternation 187 weight is [6308.99112935] and bias is 1036.1805682899576
# for iternation 188 weight is [6332.55686721] and bias is 1040.212698858264
# for iternation 189 weight is [6356.03753549] and bias is 1044.2322456168433
# for iternation 190 weight is [6379.43344026] and bias is 1048.2392537951462
# for iternation 191 weight is [6402.74488649] and bias is 1052.2337684598986
# for iternation 192 weight is [6425.97217805] and bias is 1056.2158345156874
# for iternation 193 weight is [6449.11561772] and bias is 1060.1854967055433
# for iternation 194 weight is [6472.17550718] and bias is 1064.1427996115224
# for iternation 195 weight is [6495.15214704] and bias is 1068.0877876552854
# for iternation 196 weight is [6518.04583681] and bias is 1072.0205050986742
# for iternation 197 weight is [6540.85687494] and bias is 1075.9409960442874
# for iternation 198 weight is [6563.5855588] and bias is 1079.849304436053
# for iternation 199 weight is [6586.23218469] and bias is 1083.7454740597993
# for iternation 200 weight is [6608.79704784] and bias is 1087.629548543824
# for iternation 201 weight is [6631.28044243] and bias is 1091.5015713594603
# for iternation 202 weight is [6653.68266156] and bias is 1095.361585821642
# for iternation 203 weight is [6676.00399729] and bias is 1099.2096350894662
# for iternation 204 weight is [6698.24474063] and bias is 1103.0457621667542
# for iternation 205 weight is [6720.40518155] and bias is 1106.8700099026098
# for iternation 206 weight is [6742.48560895] and bias is 1110.6824209919757
# for iternation 207 weight is [6764.48631072] and bias is 1114.483037976189
# for iternation 208 weight is [6786.4075737] and bias is 1118.2719032435332
# for iternation 209 weight is [6808.2496837] and bias is 1122.0490590297886
# for iternation 210 weight is [6830.0129255] and bias is 1125.8145474187818
# for iternation 211 weight is [6851.69758286] and bias is 1129.5684103429317
# for iternation 212 weight is [6873.30393851] and bias is 1133.3106895837946
# for iternation 213 weight is [6894.83227418] and bias is 1137.0414267726067
# for iternation 214 weight is [6916.28287056] and bias is 1140.7606633908251
# for iternation 215 weight is [6937.65600736] and bias is 1144.4684407706668
# for iternation 216 weight is [6958.95196327] and bias is 1148.1648000956452
# for iternation 217 weight is [6980.17101596] and bias is 1151.8497824011056
# for iternation 218 weight is [7001.31344214] and bias is 1155.5234285747579
# for iternation 219 weight is [7022.37951748] and bias is 1159.185779357208
# for iternation 220 weight is [7043.36951669] and bias is 1162.8368753424872
# for iternation 221 weight is [7064.28371349] and bias is 1166.4767569785788
# for iternation 222 weight is [7085.1223806] and bias is 1170.1054645679444
# for iternation 223 weight is [7105.88578977] and bias is 1173.7230382680468
# for iternation 224 weight is [7126.57421175] and bias is 1177.3295180918724
# for iternation 225 weight is [7147.18791636] and bias is 1180.9249439084504
# for iternation 226 weight is [7167.72717241] and bias is 1184.5093554433706
# for iternation 227 weight is [7188.19224776] and bias is 1188.0827922793005
# for iternation 228 weight is [7208.5834093] and bias is 1191.645293856498
# for iternation 229 weight is [7228.90092296] and bias is 1195.196899473325
# for iternation 230 weight is [7249.14505373] and bias is 1198.737648286757
# for iternation 231 weight is [7269.31606561] and bias is 1202.2675793128926
# for iternation 232 weight is [7289.41422169] and bias is 1205.78673142746
# for iternation 233 weight is [7309.43978409] and bias is 1209.2951433663218
# for iternation 234 weight is [7329.39301399] and bias is 1212.7928537259784
# for iternation 235 weight is [7349.27417164] and bias is 1216.2799009640694
# for iternation 236 weight is [7369.08351634] and bias is 1219.7563233998733
# for iternation 237 weight is [7388.82130646] and bias is 1223.222159214805
# for iternation 238 weight is [7408.48779946] and bias is 1226.6774464529121
# for iternation 239 weight is [7428.08325185] and bias is 1230.1222230213689
# for iternation 240 weight is [7447.60791922] and bias is 1233.556526690969
# for iternation 241 weight is [7467.06205626] and bias is 1236.9803950966157
# for iternation 242 weight is [7486.44591671] and bias is 1240.3938657378114
# for iternation 243 weight is [7505.75975343] and bias is 1243.7969759791442
# for iternation 244 weight is [7525.00381836] and bias is 1247.189763050774
# for iternation 245 weight is [7544.17836251] and bias is 1250.572264048915
# for iternation 246 weight is [7563.28363603] and bias is 1253.9445159363188
# for iternation 247 weight is [7582.31988814] and bias is 1257.3065555427538
# for iternation 248 weight is [7601.28736716] and bias is 1260.6584195654839
# for iternation 249 weight is [7620.18632054] and bias is 1264.0001445697453
# for iternation 250 weight is [7639.01699483] and bias is 1267.3317669892217
# for iternation 251 weight is [7657.77963567] and bias is 1270.653323126517
# for iternation 252 weight is [7676.47448786] and bias is 1273.9648491536273
# for iternation 253 weight is [7695.10179528] and bias is 1277.2663811124107
# for iternation 254 weight is [7713.66180095] and bias is 1280.5579549150557
# for iternation 255 weight is [7732.15474702] and bias is 1283.839606344547
# for iternation 256 weight is [7750.58087476] and bias is 1287.111371055132
# for iternation 257 weight is [7768.94042457] and bias is 1290.3732845727816
# for iternation 258 weight is [7787.23363599] and bias is 1293.625382295654
# for iternation 259 weight is [7805.4607477] and bias is 1296.8676994945529
# for iternation 260 weight is [7823.62199753] and bias is 1300.1002713133864
# for iternation 261 weight is [7841.71762242] and bias is 1303.323132769624
# for iternation 262 weight is [7859.7478585] and bias is 1306.5363187547503
# for iternation 263 weight is [7877.71294102] and bias is 1309.7398640347192
# for iternation 264 weight is [7895.61310441] and bias is 1312.9338032504054
# for iternation 265 weight is [7913.44858222] and bias is 1316.118170918054
# for iternation 266 weight is [7931.2196072] and bias is 1319.2930014297292
# for iternation 267 weight is [7948.92641123] and bias is 1322.4583290537614
# for iternation 268 weight is [7966.56922538] and bias is 1325.6141879351915
# for iternation 269 weight is [7984.14827987] and bias is 1328.7606120962153
# for iternation 270 weight is [8001.66380411] and bias is 1331.8976354366248
# for iternation 271 weight is [8019.11602666] and bias is 1335.0252917342493
# for iternation 272 weight is [8036.50517529] and bias is 1338.1436146453939
# for iternation 273 weight is [8053.83147692] and bias is 1341.2526377052761
# for iternation 274 weight is [8071.09515767] and bias is 1344.3523943284624
# for iternation 275 weight is [8088.29644285] and bias is 1347.4429178093017
# for iternation 276 weight is [8105.43555694] and bias is 1350.5242413223584
# for iternation 277 weight is [8122.51272363] and bias is 1353.596397922843
# for iternation 278 weight is [8139.5281658] and bias is 1356.659420547041
# for iternation 279 weight is [8156.48210553] and bias is 1359.713342012742
# for iternation 280 weight is [8173.3747641] and bias is 1362.758195019665
# for iternation 281 weight is [8190.20636198] and bias is 1365.7940121498834
# for iternation 282 weight is [8206.97711888] and bias is 1368.820825868249
# for iternation 283 weight is [8223.68725369] and bias is 1371.838668522812
# for iternation 284 weight is [8240.33698451] and bias is 1374.8475723452436
# for iternation 285 weight is [8256.92652869] and bias is 1377.8475694512529
# for iternation 286 weight is [8273.45610275] and bias is 1380.8386918410042
# for iternation 287 weight is [8289.92592248] and bias is 1383.820971399534
# for iternation 288 weight is [8306.33620285] and bias is 1386.794439897164
# for iternation 289 weight is [8322.68715809] and bias is 1389.7591289899142
# for iternation 290 weight is [8338.97900164] and bias is 1392.7150702199142
# for iternation 291 weight is [8355.21194618] and bias is 1395.6622950158126
# for iternation 292 weight is [8371.38620361] and bias is 1398.6008346931858
# for iternation 293 weight is [8387.5019851] and bias is 1401.5307204549447
# for iternation 294 weight is [8403.55950103] and bias is 1404.4519833917398
# for iternation 295 weight is [8419.55896103] and bias is 1407.364654482365
# for iternation 296 weight is [8435.50057399] and bias is 1410.2687645941605
# for iternation 297 weight is [8451.38454802] and bias is 1413.1643444834135
# for iternation 298 weight is [8467.21109052] and bias is 1416.0514247957576
# for iternation 299 weight is [8482.98040811] and bias is 1418.9300360665711
# for iternation 300 weight is [8498.69270668] and bias is 1421.8002087213738
# for iternation 301 weight is [8514.34819138] and bias is 1424.6619730762222
# for iternation 302 weight is [8529.94706662] and bias is 1427.5153593381028
# for iternation 303 weight is [8545.48953608] and bias is 1430.3603976053255
# for iternation 304 weight is [8560.9758027] and bias is 1433.1971178679134
# for iternation 305 weight is [8576.40606869] and bias is 1436.0255500079936
# for iternation 306 weight is [8591.78053553] and bias is 1438.8457238001845
# for iternation 307 weight is [8607.09940399] and bias is 1441.657668911983
# for iternation 308 weight is [8622.36287411] and bias is 1444.4614149041495
# for iternation 309 weight is [8637.57114519] and bias is 1447.2569912310928
# for iternation 310 weight is [8652.72441584] and bias is 1450.0444272412517
# for iternation 311 weight is [8667.82288395] and bias is 1452.8237521774768
# for iternation 312 weight is [8682.8667467] and bias is 1455.5949951774103
# for iternation 313 weight is [8697.85620054] and bias is 1458.3581852738646
# for iternation 314 weight is [8712.79144123] and bias is 1461.1133513951993
# for iternation 315 weight is [8727.67266383] and bias is 1463.860522365697
# for iternation 316 weight is [8742.50006269] and bias is 1466.599726905938
# for iternation 317 weight is [8757.27383147] and bias is 1469.330993633173
# for iternation 318 weight is [8771.99416311] and bias is 1472.054351061695
# for iternation 319 weight is [8786.66124989] and bias is 1474.7698276032097
# for iternation 320 weight is [8801.27528336] and bias is 1477.4774515672052
# for iternation 321 weight is [8815.83645442] and bias is 1480.1772511613187
# for iternation 322 weight is [8830.34495325] and bias is 1482.8692544917037
# for iternation 323 weight is [8844.80096937] and bias is 1485.5534895633946
# for iternation 324 weight is [8859.2046916] and bias is 1488.2299842806713
# for iternation 325 weight is [8873.55630809] and bias is 1490.8987664474205
# for iternation 326 weight is [8887.85600632] and bias is 1493.5598637674982
# for iternation 327 weight is [8902.10397308] and bias is 1496.2133038450888
# for iternation 328 weight is [8916.30039449] and bias is 1498.8591141850636
# for iternation 329 weight is [8930.44545601] and bias is 1501.4973221933385
# for iternation 330 weight is [8944.53934244] and bias is 1504.1279551772298
# for iternation 331 weight is [8958.58223789] and bias is 1506.751040345809
# for iternation 332 weight is [8972.57432582] and bias is 1509.3666048102568
# for iternation 333 weight is [8986.51578903] and bias is 1511.974675584214
# for iternation 334 weight is [9000.40680968] and bias is 1514.5752795841338
# for iternation 335 weight is [9014.24756924] and bias is 1517.1684436296305
# for iternation 336 weight is [9028.03824856] and bias is 1519.7541944438283
# for iternation 337 weight is [9041.77902781] and bias is 1522.3325586537085
# for iternation 338 weight is [9055.47008653] and bias is 1524.9035627904555
# for iternation 339 weight is [9069.11160362] and bias is 1527.4672332898008
# for iternation 340 weight is [9082.70375731] and bias is 1530.0235964923675
# for iternation 341 weight is [9096.24672522] and bias is 1532.5726786440114
# for iternation 342 weight is [9109.74068431] and bias is 1535.1145058961624
# for iternation 343 weight is [9123.18581091] and bias is 1537.6491043061646
# for iternation 344 weight is [9136.58228071] and bias is 1540.1764998376143
# for iternation 345 weight is [9149.93026879] and bias is 1542.6967183606973
# for iternation 346 weight is [9163.22994956] and bias is 1545.2097856525254
# for iternation 347 weight is [9176.48149685] and bias is 1547.7157273974706
# for iternation 348 weight is [9189.68508382] and bias is 1550.2145691874994
# for iternation 349 weight is [9202.84088304] and bias is 1552.7063365225047
# for iternation 350 weight is [9215.94906644] and bias is 1555.1910548106375
# for iternation 351 weight is [9229.00980534] and bias is 1557.668749368637
# for iternation 352 weight is [9242.02327044] and bias is 1560.139445422159
# for iternation 353 weight is [9254.98963183] and bias is 1562.603168106104
# for iternation 354 weight is [9267.90905899] and bias is 1565.0599424649436
# for iternation 355 weight is [9280.78172077] and bias is 1567.5097934530456
# for iternation 356 weight is [9293.60778545] and bias is 1569.9527459349988
# for iternation 357 weight is [9306.38742066] and bias is 1572.3888246859353
# for iternation 358 weight is [9319.12079347] and bias is 1574.8180543918531
# for iternation 359 weight is [9331.80807032] and bias is 1577.240459649936
# for iternation 360 weight is [9344.44941706] and bias is 1579.6560649688731
# for iternation 361 weight is [9357.04499894] and bias is 1582.0648947691786
# for iternation 362 weight is [9369.59498062] and bias is 1584.4669733835074
# for iternation 363 weight is [9382.09952616] and bias is 1586.8623250569715
# for iternation 364 weight is [9394.55879906] and bias is 1589.2509739474558
# for iternation 365 weight is [9406.97296218] and bias is 1591.6329441259313
# for iternation 366 weight is [9419.34217783] and bias is 1594.0082595767676
# for iternation 367 weight is [9431.66660774] and bias is 1596.376944198045
# for iternation 368 weight is [9443.94641303] and bias is 1598.7390218018647
# for iternation 369 weight is [9456.18175427] and bias is 1601.094516114658
# for iternation 370 weight is [9468.37279142] and bias is 1603.443450777495
# for iternation 371 weight is [9480.51968391] and bias is 1605.785849346391
# for iternation 372 weight is [9492.62259054] and bias is 1608.121735292613
# for iternation 373 weight is [9504.68166959] and bias is 1610.4511320029847
# for iternation 374 weight is [9516.69707874] and bias is 1612.7740627801895
# for iternation 375 weight is [9528.66897511] and bias is 1615.0905508430747
# for iternation 376 weight is [9540.59751526] and bias is 1617.4006193269515
# for iternation 377 weight is [9552.48285518] and bias is 1619.7042912838967
# for iternation 378 weight is [9564.3251503] and bias is 1622.0015896830516
# for iternation 379 weight is [9576.12455549] and bias is 1624.2925374109207
# for iternation 380 weight is [9587.88122508] and bias is 1626.5771572716685
# for iternation 381 weight is [9599.59531282] and bias is 1628.8554719874162
# for iternation 382 weight is [9611.26697191] and bias is 1631.127504198537
# for iternation 383 weight is [9622.89635502] and bias is 1633.3932764639499
# for iternation 384 weight is [9634.48361425] and bias is 1635.6528112614124
# for iternation 385 weight is [9646.02890115] and bias is 1637.9061309878134
# for iternation 386 weight is [9657.53236675] and bias is 1640.1532579594634
# for iternation 387 weight is [9668.99416151] and bias is 1642.394214412385
# for iternation 388 weight is [9680.41443536] and bias is 1644.6290225026012
# for iternation 389 weight is [9691.79333769] and bias is 1646.857704306423
# for iternation 390 weight is [9703.13101736] and bias is 1649.0802818207378
# for iternation 391 weight is [9714.42762268] and bias is 1651.2967769632928
# for iternation 392 weight is [9725.68330143] and bias is 1653.5072115729818
# for iternation 393 weight is [9736.89820086] and bias is 1655.7116074101273
# for iternation 394 weight is [9748.0724677] and bias is 1657.9099861567645
# for iternation 395 weight is [9759.20624815] and bias is 1660.1023694169219
# for iternation 396 weight is [9770.29968786] and bias is 1662.2887787169027
# for iternation 397 weight is [9781.35293198] and bias is 1664.469235505564
# for iternation 398 weight is [9792.36612514] and bias is 1666.6437611545957
# for iternation 399 weight is [9803.33941144] and bias is 1668.8123769587978
# for iternation 400 weight is [9814.27293445] and bias is 1670.9751041363577
# for iternation 401 weight is [9825.16683724] and bias is 1673.1319638291247
# for iternation 402 weight is [9836.02126237] and bias is 1675.282977102886
# for iternation 403 weight is [9846.83635188] and bias is 1677.4281649476393
# for iternation 404 weight is [9857.61224728] and bias is 1679.5675482778659
# for iternation 405 weight is [9868.34908961] and bias is 1681.7011479328025
# for iternation 406 weight is [9879.04701937] and bias is 1683.8289846767116
# for iternation 407 weight is [9889.70617656] and bias is 1685.9510791991515
# for iternation 408 weight is [9900.3267007] and bias is 1688.067452115245
# for iternation 409 weight is [9910.90873077] and bias is 1690.1781239659472
# for iternation 410 weight is [9921.45240528] and bias is 1692.283115218312
# for iternation 411 weight is [9931.95786223] and bias is 1694.3824462657587
# for iternation 412 weight is [9942.42523912] and bias is 1696.4761374283364
# for iternation 413 weight is [9952.85467297] and bias is 1698.564208952988
# for iternation 414 weight is [9963.2463003] and bias is 1700.6466810138136
# for iternation 415 weight is [9973.60025712] and bias is 1702.7235737123317
# for iternation 416 weight is [9983.91667898] and bias is 1704.7949070777413
# for iternation 417 weight is [9994.19570092] and bias is 1706.8607010671817
# for iternation 418 weight is [10004.43745751] and bias is 1708.920975565992
# for iternation 419 weight is [10014.64208283] and bias is 1710.9757503879684
# for iternation 420 weight is [10024.80971047] and bias is 1713.0250452756234
# for iternation 421 weight is [10034.94047355] and bias is 1715.0688799004404
# for iternation 422 weight is [10045.03450471] and bias is 1717.1072738631306
# for iternation 423 weight is [10055.09193611] and bias is 1719.1402466938869
# for iternation 424 weight is [10065.11289943] and bias is 1721.1678178526377
# for iternation 425 weight is [10075.09752588] and bias is 1723.1900067293
# for iternation 426 weight is [10085.04594621] and bias is 1725.2068326440312
# for iternation 427 weight is [10094.95829067] and bias is 1727.2183148474799
# for iternation 428 weight is [10104.83468908] and bias is 1729.2244725210358
# for iternation 429 weight is [10114.67527076] and bias is 1731.2253247770793
# for iternation 430 weight is [10124.48016457] and bias is 1733.2208906592298
# for iternation 431 weight is [10134.24949893] and bias is 1735.2111891425927
# for iternation 432 weight is [10143.98340178] and bias is 1737.1962391340064
# for iternation 433 weight is [10153.68200059] and bias is 1739.176059472287
# for iternation 434 weight is [10163.34542239] and bias is 1741.1506689284745
# for iternation 435 weight is [10172.97379375] and bias is 1743.120086206075
# for iternation 436 weight is [10182.56724077] and bias is 1745.0843299413048
# for iternation 437 weight is [10192.12588912] and bias is 1747.0434187033322
# for iternation 438 weight is [10201.64986399] and bias is 1748.9973709945186
# for iternation 439 weight is [10211.13929014] and bias is 1750.946205250659
# for iternation 440 weight is [10220.59429188] and bias is 1752.8899398412211
# for iternation 441 weight is [10230.01499306] and bias is 1754.828593069585
# for iternation 442 weight is [10239.40151711] and bias is 1756.7621831732793
# for iternation 443 weight is [10248.75398697] and bias is 1758.6907283242197
# for iternation 444 weight is [10258.07252519] and bias is 1760.6142466289439
# for iternation 445 weight is [10267.35725385] and bias is 1762.5327561288473
# for iternation 446 weight is [10276.60829459] and bias is 1764.4462748004173
# for iternation 447 weight is [10285.82576862] and bias is 1766.354820555467
# for iternation 448 weight is [10295.00979671] and bias is 1768.2584112413676
# for iternation 449 weight is [10304.16049921] and bias is 1770.1570646412802
# for iternation 450 weight is [10313.27799601] and bias is 1772.0507984743867
# for iternation 451 weight is [10322.36240659] and bias is 1773.939630396121
# for iternation 452 weight is [10331.41384999] and bias is 1775.823577998397
# for iternation 453 weight is [10340.43244484] and bias is 1777.7026588098379
# for iternation 454 weight is [10349.41830931] and bias is 1779.5768902960037
# for iternation 455 weight is [10358.37156117] and bias is 1781.4462898596184
# for iternation 456 weight is [10367.29231776] and bias is 1783.3108748407956
# for iternation 457 weight is [10376.180696] and bias is 1785.1706625172635
# for iternation 458 weight is [10385.03681238] and bias is 1787.0256701045905
# for iternation 459 weight is [10393.86078298] and bias is 1788.8759147564078
# for iternation 460 weight is [10402.65272347] and bias is 1790.7214135646327
# for iternation 461 weight is [10411.41274908] and bias is 1792.5621835596903
# for iternation 462 weight is [10420.14097465] and bias is 1794.398241710735
# for iternation 463 weight is [10428.83751459] and bias is 1796.229604925871
# for iternation 464 weight is [10437.5024829] and bias is 1798.0562900523717
# for iternation 465 weight is [10446.13599319] and bias is 1799.8783138768988
# for iternation 466 weight is [10454.73815863] and bias is 1801.6956931257205
# for iternation 467 weight is [10463.30909201] and bias is 1803.5084444649278
# for iternation 468 weight is [10471.84890569] and bias is 1805.3165845006524
# for iternation 469 weight is [10480.35771165] and bias is 1807.1201297792816
# for iternation 470 weight is [10488.83562146] and bias is 1808.919096787673
# for iternation 471 weight is [10497.28274626] and bias is 1810.7135019533696
# for iternation 472 weight is [10505.69919684] and bias is 1812.5033616448127
# for iternation 473 weight is [10514.08508356] and bias is 1814.288692171554
# for iternation 474 weight is [10522.44051637] and bias is 1816.0695097844684
# for iternation 475 weight is [10530.76560487] and bias is 1817.8458306759646
# for iternation 476 weight is [10539.06045822] and bias is 1819.6176709801955
# for iternation 477 weight is [10547.32518521] and bias is 1821.385046773268
# for iternation 478 weight is [10555.55989424] and bias is 1823.1479740734512
# for iternation 479 weight is [10563.76469332] and bias is 1824.9064688413857
# for iternation 480 weight is [10571.93969005] and bias is 1826.6605469802896
# for iternation 481 weight is [10580.08499166] and bias is 1828.4102243361658
# for iternation 482 weight is [10588.20070501] and bias is 1830.1555166980081
# for iternation 483 weight is [10596.28693655] and bias is 1831.8964397980053
# for iternation 484 weight is [10604.34379234] and bias is 1833.6330093117467
# for iternation 485 weight is [10612.3713781] and bias is 1835.3652408584253
# for iternation 486 weight is [10620.36979913] and bias is 1837.0931500010402
# for iternation 487 weight is [10628.33916037] and bias is 1838.8167522465997
# for iternation 488 weight is [10636.27956637] and bias is 1840.536063046322
# for iternation 489 weight is [10644.19112131] and bias is 1842.251097795836
# for iternation 490 weight is [10652.07392901] and bias is 1843.9618718353818
# for iternation 491 weight is [10659.92809289] and bias is 1845.6684004500098
# for iternation 492 weight is [10667.75371602] and bias is 1847.3706988697788
# for iternation 493 weight is [10675.55090108] and bias is 1849.0687822699542
# for iternation 494 weight is [10683.3197504] and bias is 1850.7626657712053
# for iternation 495 weight is [10691.06036593] and bias is 1852.4523644398012
# for iternation 496 weight is [10698.77284925] and bias is 1854.1378932878072
# for iternation 497 weight is [10706.45730159] and bias is 1855.8192672732791
# for iternation 498 weight is [10714.11382379] and bias is 1857.4965013004585
# for iternation 499 weight is [10721.74251636] and bias is 1859.1696102199649
# for iternation 500 weight is [10729.34347943] and bias is 1860.8386088289901
# for iternation 501 weight is [10736.91681276] and bias is 1862.50351187149
# for iternation 502 weight is [10744.46261576] and bias is 1864.1643340383755
# for iternation 503 weight is [10751.9809875] and bias is 1865.821089967704
# for iternation 504 weight is [10759.47202668] and bias is 1867.4737942448692
# for iternation 505 weight is [10766.93583162] and bias is 1869.122461402791
# for iternation 506 weight is [10774.37250033] and bias is 1870.7671059221038
# for iternation 507 weight is [10781.78213044] and bias is 1872.407742231345
# for iternation 508 weight is [10789.16481924] and bias is 1874.0443847071422
# for iternation 509 weight is [10796.52066366] and bias is 1875.6770476744
# for iternation 510 weight is [10803.84976028] and bias is 1877.305745406486
# for iternation 511 weight is [10811.15220536] and bias is 1878.9304921254168
# for iternation 512 weight is [10818.42809477] and bias is 1880.5513020020417
# for iternation 513 weight is [10825.67752407] and bias is 1882.1681891562278
# for iternation 514 weight is [10832.90058847] and bias is 1883.7811676570427
# for iternation 515 weight is [10840.09738282] and bias is 1885.3902515229377
# for iternation 516 weight is [10847.26800165] and bias is 1886.9954547219297
# for iternation 517 weight is [10854.41253913] and bias is 1888.596791171783
# for iternation 518 weight is [10861.53108911] and bias is 1890.1942747401895
# for iternation 519 weight is [10868.62374509] and bias is 1891.7879192449493
# for iternation 520 weight is [10875.69060024] and bias is 1893.37773845415
# for iternation 521 weight is [10882.73174739] and bias is 1894.9637460863457
# for iternation 522 weight is [10889.74727904] and bias is 1896.5459558107352
# for iternation 523 weight is [10896.73728735] and bias is 1898.1243812473392
# for iternation 524 weight is [10903.70186417] and bias is 1899.699035967178
# for iternation 525 weight is [10910.64110098] and bias is 1901.2699334924466
# for iternation 526 weight is [10917.55508897] and bias is 1902.8370872966918
# for iternation 527 weight is [10924.44391899] and bias is 1904.4005108049864
# for iternation 528 weight is [10931.30768155] and bias is 1905.9602173941037
# for iternation 529 weight is [10938.14646684] and bias is 1907.5162203926907
# for iternation 530 weight is [10944.96036474] and bias is 1909.0685330814426
# for iternation 531 weight is [10951.74946479] and bias is 1910.6171686932744
# for iternation 532 weight is [10958.51385622] and bias is 1912.1621404134926
# for iternation 533 weight is [10965.25362792] and bias is 1913.7034613799672
# for iternation 534 weight is [10971.96886849] and bias is 1915.2411446833019
# for iternation 535 weight is [10978.65966618] and bias is 1916.775203367004
# for iternation 536 weight is [10985.32610894] and bias is 1918.3056504276547
# for iternation 537 weight is [10991.96828441] and bias is 1919.8324988150766
# for iternation 538 weight is [10998.58627989] and bias is 1921.3557614325032
# for iternation 539 weight is [11005.18018239] and bias is 1922.8754511367458
# for iternation 540 weight is [11011.7500786] and bias is 1924.391580738361
# for iternation 541 weight is [11018.29605488] and bias is 1925.9041630018162
# for iternation 542 weight is [11024.81819732] and bias is 1927.4132106456564
# for iternation 543 weight is [11031.31659166] and bias is 1928.918736342669
# for iternation 544 weight is [11037.79132335] and bias is 1930.4207527200485
# for iternation 545 weight is [11044.24247752] and bias is 1931.9192723595606
# for iternation 546 weight is [11050.67013902] and bias is 1933.4143077977055
# for iternation 547 weight is [11057.07439238] and bias is 1934.9058715258807
# for iternation 548 weight is [11063.4553218] and bias is 1936.3939759905431
# for iternation 549 weight is [11069.81301122] and bias is 1937.8786335933717
# for iternation 550 weight is [11076.14754426] and bias is 1939.3598566914275
# for iternation 551 weight is [11082.45900423] and bias is 1940.8376575973143
# for iternation 552 weight is [11088.74747415] and bias is 1942.3120485793393
# for iternation 553 weight is [11095.01303674] and bias is 1943.7830418616718
# for iternation 554 weight is [11101.25577443] and bias is 1945.250649624502
# for iternation 555 weight is [11107.47576933] and bias is 1946.7148840042
# for iternation 556 weight is [11113.67310328] and bias is 1948.1757570934722
# for iternation 557 weight is [11119.84785782] and bias is 1949.6332809415194
# for iternation 558 weight is [11126.00011418] and bias is 1951.087467554193
# for iternation 559 weight is [11132.12995332] and bias is 1952.538328894151
# for iternation 560 weight is [11138.2374559] and bias is 1953.9858768810134
# for iternation 561 weight is [11144.32270228] and bias is 1955.4301233915169
# for iternation 562 weight is [11150.38577255] and bias is 1956.8710802596693
# for iternation 563 weight is [11156.42674649] and bias is 1958.3087592769034
# for iternation 564 weight is [11162.44570361] and bias is 1959.7431721922296
# for iternation 565 weight is [11168.44272312] and bias is 1961.1743307123895
# for iternation 566 weight is [11174.41788397] and bias is 1962.602246502007
# for iternation 567 weight is [11180.3712648] and bias is 1964.0269311837399
# for iternation 568 weight is [11186.30294398] and bias is 1965.4483963384318
# for iternation 569 weight is [11192.21299959] and bias is 1966.866653505262
# for iternation 570 weight is [11198.10150943] and bias is 1968.281714181895
# for iternation 571 weight is [11203.96855103] and bias is 1969.6935898246304
# for iternation 572 weight is [11209.81420163] and bias is 1971.1022918485514
# for iternation 573 weight is [11215.6385382] and bias is 1972.507831627673
# for iternation 574 weight is [11221.44163744] and bias is 1973.910220495091
# for iternation 575 weight is [11227.22357574] and bias is 1975.3094697431266
# for iternation 576 weight is [11232.98442926] and bias is 1976.705590623476
# for iternation 577 weight is [11238.72427385] and bias is 1978.0985943473547
# for iternation 578 weight is [11244.44318511] and bias is 1979.4884920856439
# for iternation 579 weight is [11250.14123836] and bias is 1980.8752949690352
# for iternation 580 weight is [11255.81850865] and bias is 1982.2590140881753
# for iternation 581 weight is [11261.47507076] and bias is 1983.6396604938107
# for iternation 582 weight is [11267.11099919] and bias is 1985.0172451969302
# for iternation 583 weight is [11272.7263682] and bias is 1986.3917791689087
# for iternation 584 weight is [11278.32125174] and bias is 1987.7632733416494
# for iternation 585 weight is [11283.89572355] and bias is 1989.1317386077262
# for iternation 586 weight is [11289.44985704] and bias is 1990.4971858205245
# for iternation 587 weight is [11294.98372542] and bias is 1991.8596257943825
# for iternation 588 weight is [11300.49740158] and bias is 1993.2190693047323
# for iternation 589 weight is [11305.99095819] and bias is 1994.575527088239
# for iternation 590 weight is [11311.46446764] and bias is 1995.9290098429403
# for iternation 591 weight is [11316.91800206] and bias is 1997.2795282283864
# for iternation 592 weight is [11322.35163332] and bias is 1998.627092865777
# for iternation 593 weight is [11327.76543304] and bias is 1999.9717143381006
# for iternation 594 weight is [11333.15947257] and bias is 2001.313403190271
# for iternation 595 weight is [11338.53382301] and bias is 2002.6521699292648
# for iternation 596 weight is [11343.88855521] and bias is 2003.9880250242581
# for iternation 597 weight is [11349.22373975] and bias is 2005.320978906762
# for iternation 598 weight is [11354.53944697] and bias is 2006.6510419707583
# for iternation 599 weight is [11359.83574694] and bias is 2007.9782245728343
# for iternation 600 weight is [11365.11270951] and bias is 2009.3025370323178
# for iternation 601 weight is [11370.37040425] and bias is 2010.623989631411
# for iternation 602 weight is [11375.60890048] and bias is 2011.9425926153235
# for iternation 603 weight is [11380.82826729] and bias is 2013.2583561924066
# for iternation 604 weight is [11386.0285735] and bias is 2014.5712905342846
# for iternation 605 weight is [11391.2098877] and bias is 2015.8814057759878
# for iternation 606 weight is [11396.37227822] and bias is 2017.1887120160839
# for iternation 607 weight is [11401.51581315] and bias is 2018.4932193168088
# for iternation 608 weight is [11406.64056035] and bias is 2019.794937704198
# for iternation 609 weight is [11411.7465874] and bias is 2021.0938771682163
# for iternation 610 weight is [11416.83396166] and bias is 2022.3900476628883
# for iternation 611 weight is [11421.90275026] and bias is 2023.6834591064264
# for iternation 612 weight is [11426.95302006] and bias is 2024.974121381361
# for iternation 613 weight is [11431.9848377] and bias is 2026.2620443346682
# for iternation 614 weight is [11436.99826957] and bias is 2027.5472377778976
# for iternation 615 weight is [11441.99338182] and bias is 2028.8297114873005
# for iternation 616 weight is [11446.97024038] and bias is 2030.1094752039558
# for iternation 617 weight is [11451.92891092] and bias is 2031.3865386338975
# for iternation 618 weight is [11456.86945888] and bias is 2032.6609114482403
# for iternation 619 weight is [11461.79194948] and bias is 2033.9326032833053
# for iternation 620 weight is [11466.69644768] and bias is 2035.2016237407452
# for iternation 621 weight is [11471.58301822] and bias is 2036.467982387669
# for iternation 622 weight is [11476.45172562] and bias is 2037.7316887567667
# for iternation 623 weight is [11481.30263414] and bias is 2038.9927523464323
# for iternation 624 weight is [11486.13580783] and bias is 2040.251182620888
# for iternation 625 weight is [11490.9513105] and bias is 2041.5069890103064
# for iternation 626 weight is [11495.74920573] and bias is 2042.7601809109337
# for iternation 627 weight is [11500.52955688] and bias is 2044.0107676852115
# for iternation 628 weight is [11505.29242707] and bias is 2045.2587586618981
# for iternation 629 weight is [11510.03787921] and bias is 2046.5041631361905
# for iternation 630 weight is [11514.76597597] and bias is 2047.7469903698438
# for iternation 631 weight is [11519.47677979] and bias is 2048.987249591293
# for iternation 632 weight is [11524.17035289] and bias is 2050.2249499957725
# for iternation 633 weight is [11528.84675728] and bias is 2051.460100745434
# for iternation 634 weight is [11533.50605473] and bias is 2052.6927109694675
# ...
# for iternation 792 weight is [12090.80508971] and bias is 2220.8551865816185
# for iternation 793 weight is [12093.39778793] and bias is 2221.780413460473
# for iternation 794 weight is [12095.98087697] and bias is 2222.7042078391996
# for iternation 795 weight is [12098.55439141] and bias is 2223.6265748278706
# for iternation 796 weight is [12101.11836571] and bias is 2224.547519518175
# for iternation 797 weight is [12103.6728342] and bias is 2225.467046983483
# for iternation 798 weight is [12106.21783107] and bias is 2226.385162278915
# for iternation 799 weight is [12108.75339043] and bias is 2227.301870441402
# for iternation 800 weight is [12111.27954622] and bias is 2228.2171764897575
# for iternation 801 weight is [12113.79633228] and bias is 2229.131085424737
# for iternation 802 weight is [12116.30378234] and bias is 2230.0436022291074
# for iternation 803 weight is [12118.80192998] and bias is 2230.9547318677073
# for iternation 804 weight is [12121.29080868] and bias is 2231.8644792875157
# for iternation 805 weight is [12123.7704518] and bias is 2232.772849417714
# for iternation 806 weight is [12126.24089257] and bias is 2233.6798471697507
# for iternation 807 weight is [12128.70216411] and bias is 2234.5854774374043
# for iternation 808 weight is [12131.1542994] and bias is 2235.489745096848
# for iternation 809 weight is [12133.59733133] and bias is 2236.3926550067126
# for iternation 810 weight is [12136.03129265] and bias is 2237.2942120081498
# for iternation 811 weight is [12138.45621601] and bias is 2238.194420924894
# for iternation 812 weight is [12140.87213393] and bias is 2239.093286563327
# for iternation 813 weight is [12143.27907881] and bias is 2239.9908137125394
# for iternation 814 weight is [12145.67708294] and bias is 2240.887007144391
# for iternation 815 weight is [12148.06617851] and bias is 2241.781871613576
# for iternation 816 weight is [12150.44639755] and bias is 2242.6754118576832
# for iternation 817 weight is [12152.81777203] and bias is 2243.5676325972568
# for iternation 818 weight is [12155.18033376] and bias is 2244.458538535859
# for iternation 819 weight is [12157.53411446] and bias is 2245.348134360131
# for iternation 820 weight is [12159.87914572] and bias is 2246.2364247398527
# for iternation 821 weight is [12162.21545903] and bias is 2247.123414328005
# for iternation 822 weight is [12164.54308577] and bias is 2248.009107760828
# for iternation 823 weight is [12166.86205719] and bias is 2248.8935096578844
# for iternation 824 weight is [12169.17240444] and bias is 2249.7766246221163
# for iternation 825 weight is [12171.47415855] and bias is 2250.6584572399074
# for iternation 826 weight is [12173.76735044] and bias is 2251.5390120811408
# for iternation 827 weight is [12176.05201094] and bias is 2252.4182936992597
# for iternation 828 weight is [12178.32817073] and bias is 2253.296306631326
# for iternation 829 weight is [12180.5958604] and bias is 2254.1730553980788
# for iternation 830 weight is [12182.85511045] and bias is 2255.048544503994
# for iternation 831 weight is [12185.10595123] and bias is 2255.922778437342
# for iternation 832 weight is [12187.34841301] and bias is 2256.795761670247
# for iternation 833 weight is [12189.58252595] and bias is 2257.6674986587436
# for iternation 834 weight is [12191.80832008] and bias is 2258.537993842837
# for iternation 835 weight is [12194.02582534] and bias is 2259.407251646557
# for iternation 836 weight is [12196.23507156] and bias is 2260.2752764780203
# for iternation 837 weight is [12198.43608846] and bias is 2261.142072729483
# for iternation 838 weight is [12200.62890566] and bias is 2262.007644777401
# for iternation 839 weight is [12202.81355265] and bias is 2262.871996982485
# for iternation 840 weight is [12204.99005885] and bias is 2263.7351336897586
# for iternation 841 weight is [12207.15845354] and bias is 2264.5970592286135
# for iternation 842 weight is [12209.31876593] and bias is 2265.457777912866
# for iternation 843 weight is [12211.47102508] and bias is 2266.3172940408135
# for iternation 844 weight is [12213.61525999] and bias is 2267.1756118952903
# for iternation 845 weight is [12215.75149952] and bias is 2268.0327357437222
# for iternation 846 weight is [12217.87977246] and bias is 2268.888669838184
# for iternation 847 weight is [12220.00010747] and bias is 2269.743418415452
# for iternation 848 weight is [12222.11253311] and bias is 2270.596985697062
# for iternation 849 weight is [12224.21707784] and bias is 2271.449375889361
# for iternation 850 weight is [12226.31377004] and bias is 2272.3005931835646
# for iternation 851 weight is [12228.40263795] and bias is 2273.1506417558103
# for iternation 852 weight is [12230.48370973] and bias is 2273.9995257672117
# for iternation 853 weight is [12232.55701344] and bias is 2274.8472493639124
# for iternation 854 weight is [12234.62257703] and bias is 2275.6938166771397
# for iternation 855 weight is [12236.68042836] and bias is 2276.53923182326
# for iternation 856 weight is [12238.73059518] and bias is 2277.3834989038287
# for iternation 857 weight is [12240.77310514] and bias is 2278.226622005648
# for iternation 858 weight is [12242.80798579] and bias is 2279.068605200817
# for iternation 859 weight is [12244.8352646] and bias is 2279.909452546784
# for iternation 860 weight is [12246.85496892] and bias is 2280.749168086402
# for iternation 861 weight is [12248.867126] and bias is 2281.5877558479788
# for iternation 862 weight is [12250.87176301] and bias is 2282.425219845331
# for iternation 863 weight is [12252.86890701] and bias is 2283.261564077835
# for iternation 864 weight is [12254.85858496] and bias is 2284.096792530479
# for iternation 865 weight is [12256.84082373] and bias is 2284.9309091739156
# for iternation 866 weight is [12258.81565009] and bias is 2285.7639179645125
# for iternation 867 weight is [12260.78309072] and bias is 2286.5958228444047
# for iternation 868 weight is [12262.74317219] and bias is 2287.4266277415445
# for iternation 869 weight is [12264.695921] and bias is 2288.256336569754
# for iternation 870 weight is [12266.64136351] and bias is 2289.0849532287743
# for iternation 871 weight is [12268.57952604] and bias is 2289.9124816043186
# for iternation 872 weight is [12270.51043477] and bias is 2290.73892556812
# for iternation 873 weight is [12272.43411582] and bias is 2291.5642889779833
# for iternation 874 weight is [12274.35059518] and bias is 2292.3885756778345
# for iternation 875 weight is [12276.25989879] and bias is 2293.2117894977714
# for iternation 876 weight is [12278.16205245] and bias is 2294.033934254113
# for iternation 877 weight is [12280.05708191] and bias is 2294.855013749448
# for iternation 878 weight is [12281.94501279] and bias is 2295.675031772687
# for iternation 879 weight is [12283.82587065] and bias is 2296.4939920991083
# for iternation 880 weight is [12285.69968094] and bias is 2297.311898490409
# for iternation 881 weight is [12287.56646902] and bias is 2298.128754694754
# for iternation 882 weight is [12289.42626017] and bias is 2298.944564446824
# for iternation 883 weight is [12291.27907955] and bias is 2299.7593314678634
# for iternation 884 weight is [12293.12495226] and bias is 2300.5730594657302
# for iternation 885 weight is [12294.96390331] and bias is 2301.385752134943
# for iternation 886 weight is [12296.79595759] and bias is 2302.1974131567285
# for iternation 887 weight is [12298.62113993] and bias is 2303.008046199072
# for iternation 888 weight is [12300.43947507] and bias is 2303.817654916762
# for iternation 889 weight is [12302.25098763] and bias is 2304.626242951439
# for iternation 890 weight is [12304.05570217] and bias is 2305.433813931643
# for iternation 891 weight is [12305.85364316] and bias is 2306.240371472859
# for iternation 892 weight is [12307.64483498] and bias is 2307.045919177567
# for iternation 893 weight is [12309.4293019] and bias is 2307.8504606352867
# for iternation 894 weight is [12311.20706814] and bias is 2308.6539994226237
# for iternation 895 weight is [12312.97815781] and bias is 2309.4565391033175
# for iternation 896 weight is [12314.74259493] and bias is 2310.2580832282865
# for iternation 897 weight is [12316.50040345] and bias is 2311.0586353356753
# for iternation 898 weight is [12318.25160721] and bias is 2311.8581989508994
# for iternation 899 weight is [12319.99623] and bias is 2312.656777586692
# for iternation 900 weight is [12321.73429549] and bias is 2313.4543747431494
# for iternation 901 weight is [12323.46582728] and bias is 2314.250993907776
# for iternation 902 weight is [12325.19084888] and bias is 2315.0466385555296
# for iternation 903 weight is [12326.90938372] and bias is 2315.8413121488675
# for iternation 904 weight is [12328.62145516] and bias is 2316.6350181377907
# for iternation 905 weight is [12330.32708644] and bias is 2317.4277599598886
# for iternation 906 weight is [12332.02630074] and bias is 2318.219541040384
# for iternation 907 weight is [12333.71912116] and bias is 2319.0103647921774
# for iternation 908 weight is [12335.40557071] and bias is 2319.800234615892
# for iternation 909 weight is [12337.08567232] and bias is 2320.5891538999167
# for iternation 910 weight is [12338.75944882] and bias is 2321.377126020451
# for iternation 911 weight is [12340.42692299] and bias is 2322.164154341549
# for iternation 912 weight is [12342.0881175] and bias is 2322.950242215161
# for iternation 913 weight is [12343.74305496] and bias is 2323.7353929811807
# for iternation 914 weight is [12345.39175787] and bias is 2324.5196099674854
# for iternation 915 weight is [12347.03424869] and bias is 2325.302896489981
# for iternation 916 weight is [12348.67054976] and bias is 2326.085255852644
# for iternation 917 weight is [12350.30068336] and bias is 2326.8666913475654
# for iternation 918 weight is [12351.92467169] and bias is 2327.647206254993
# for iternation 919 weight is [12353.54253686] and bias is 2328.4268038433734
# for iternation 920 weight is [12355.1543009] and bias is 2329.2054873693955
# for iternation 921 weight is [12356.75998579] and bias is 2329.9832600780323
# for iternation 922 weight is [12358.35961338] and bias is 2330.760125202583
# for iternation 923 weight is [12359.95320549] and bias is 2331.5360859647153
# for iternation 924 weight is [12361.54078383] and bias is 2332.3111455745066
# for iternation 925 weight is [12363.12237005] and bias is 2333.0853072304867
# for iternation 926 weight is [12364.69798571] and bias is 2333.8585741196785
# for iternation 927 weight is [12366.26765229] and bias is 2334.63094941764
# for iternation 928 weight is [12367.83139122] and bias is 2335.4024362885043
# for iternation 929 weight is [12369.38922381] and bias is 2336.1730378850225
# for iternation 930 weight is [12370.94117134] and bias is 2336.9427573486037
# for iternation 931 weight is [12372.48725496] and bias is 2337.711597809356
# for iternation 932 weight is [12374.0274958] and bias is 2338.479562386127
# for iternation 933 weight is [12375.56191488] and bias is 2339.2466541865433
# for iternation 934 weight is [12377.09053315] and bias is 2340.0128763070534
# for iternation 935 weight is [12378.61337148] and bias is 2340.778231832966
# for iternation 936 weight is [12380.13045068] and bias is 2341.5427238384905
# for iternation 937 weight is [12381.64179148] and bias is 2342.306355386777
# for iternation 938 weight is [12383.14741452] and bias is 2343.0691295299553
# for iternation 939 weight is [12384.64734039] and bias is 2343.8310493091767
# for iternation 940 weight is [12386.14158958] and bias is 2344.592117754651
# for iternation 941 weight is [12387.63018253] and bias is 2345.3523378856876
# for iternation 942 weight is [12389.1131396] and bias is 2346.1117127107336
# for iternation 943 weight is [12390.59048106] and bias is 2346.8702452274138
# for iternation 944 weight is [12392.06222713] and bias is 2347.6279384225686
# for iternation 945 weight is [12393.52839794] and bias is 2348.384795272294
# for iternation 946 weight is [12394.98901357] and bias is 2349.1408187419797
# for iternation 947 weight is [12396.44409399] and bias is 2349.896011786347
# for iternation 948 weight is [12397.89365914] and bias is 2350.6503773494883
# for iternation 949 weight is [12399.33772887] and bias is 2351.4039183649047
# for iternation 950 weight is [12400.77632294] and bias is 2352.1566377555437
# for iternation 951 weight is [12402.20946107] and bias is 2352.908538433838
# for iternation 952 weight is [12403.63716289] and bias is 2353.659623301744
# for iternation 953 weight is [12405.05944797] and bias is 2354.4098952507766
# for iternation 954 weight is [12406.47633581] and bias is 2355.15935716205
# for iternation 955 weight is [12407.88784582] and bias is 2355.9080119063137
# for iternation 956 weight is [12409.29399737] and bias is 2356.655862343989
# for iternation 957 weight is [12410.69480973] and bias is 2357.4029113252086
# for iternation 958 weight is [12412.09030212] and bias is 2358.14916168985
# for iternation 959 weight is [12413.4804937] and bias is 2358.894616267576
# for iternation 960 weight is [12414.86540353] and bias is 2359.6392778778695
# for iternation 961 weight is [12416.24505062] and bias is 2360.38314933007
# for iternation 962 weight is [12417.61945393] and bias is 2361.1262334234116
# for iternation 963 weight is [12418.98863231] and bias is 2361.8685329470572
# for iternation 964 weight is [12420.35260458] and bias is 2362.6100506801367
# for iternation 965 weight is [12421.71138947] and bias is 2363.3507893917827
# for iternation 966 weight is [12423.06500565] and bias is 2364.0907518411645
# for iternation 967 weight is [12424.41347172] and bias is 2364.829940777527
# for iternation 968 weight is [12425.75680622] and bias is 2365.5683589402247
# for iternation 969 weight is [12427.09502761] and bias is 2366.3060090587564
# for iternation 970 weight is [12428.42815431] and bias is 2367.0428938528034
# for iternation 971 weight is [12429.75620464] and bias is 2367.779016032262
# for iternation 972 weight is [12431.07919687] and bias is 2368.51437829728
# for iternation 973 weight is [12432.39714922] and bias is 2369.248983338292
# for iternation 974 weight is [12433.71007981] and bias is 2369.982833836054
# for iternation 975 weight is [12435.01800673] and bias is 2370.715932461678
# for iternation 976 weight is [12436.32094798] and bias is 2371.448281876668
# for iternation 977 weight is [12437.6189215] and bias is 2372.179884732951
# for iternation 978 weight is [12438.91194518] and bias is 2372.9107436729164
# for iternation 979 weight is [12440.20003682] and bias is 2373.6408613294466
# for iternation 980 weight is [12441.48321419] and bias is 2374.370240325953
# for iternation 981 weight is [12442.76149496] and bias is 2375.0988832764097
# for iternation 982 weight is [12444.03489676] and bias is 2375.8267927853863
# for iternation 983 weight is [12445.30343716] and bias is 2376.5539714480833
# for iternation 984 weight is [12446.56713363] and bias is 2377.2804218503657
# for iternation 985 weight is [12447.82600363] and bias is 2378.006146568796
# for iternation 986 weight is [12449.08006452] and bias is 2378.731148170667
# for iternation 987 weight is [12450.32933362] and bias is 2379.4554292140365
# for iternation 988 weight is [12451.57382815] and bias is 2380.17899224776
# for iternation 989 weight is [12452.81356532] and bias is 2380.901839811524
# for iternation 990 weight is [12454.04856224] and bias is 2381.6239744358786
# for iternation 991 weight is [12455.27883598] and bias is 2382.34539864227
# for iternation 992 weight is [12456.50440353] and bias is 2383.0661149430744
# for iternation 993 weight is [12457.72528183] and bias is 2383.7861258416297
# for iternation 994 weight is [12458.94148776] and bias is 2384.5054338322684
# for iternation 995 weight is [12460.15303814] and bias is 2385.22404140035
# for iternation 996 weight is [12461.35994972] and bias is 2385.9419510222933
# for iternation 997 weight is [12462.5622392] and bias is 2386.6591651656086
# for iternation 998 weight is [12463.75992321] and bias is 2387.375686288929
# for iternation 999 weight is [12464.95301833] and bias is 2388.091516842044
# for iternation 1000 weight is [12466.14154107] and bias is 2388.806659265929

# %%
#calculating predicted values
Y_pred = model.predict(X_test=X_test)

# %%
#actual answers
Y_test
# Out:
# array([112635,  67938, 113812,  83088,  64445,  57189])

# %%
mean_absolute_error = np.sum(abs(Y_pred-Y_test))/len(Y_test)
mean_absolute_error
# Out:
# np.float64(11427.225194686946)

# %%
mean_squared_error = np.sum((Y_pred-Y_test)**2)/len(Y_test)
mean_squared_error
# Out:
# np.float64(162336980.44131398)

# %% [markdown]
# inferences from this learning:
# - overfitting isn't possible in linear regression
# - adjusting learning rate and no. of iterations improves a lot
# - do standardization of the data for good results
# - use only in case of linear relationships
# - tuning parameters like learning rate and no. of iterations also effect model parameters
